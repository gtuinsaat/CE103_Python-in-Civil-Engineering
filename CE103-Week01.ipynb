# %% [markdown]
# ### CE103- INTRODUCTION TO COMPUTING

# %% [markdown]
# This week:
# - Variable
#
# - List

# %% [markdown]
# ---
# ## Variable

# %% [markdown]
# A variable is somtehing.

# %% [markdown]
# I feel good

# %% [markdown]
# Aloha
